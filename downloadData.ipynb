# %%
import pandas as pd
import numpy as np
import os
import sys
import simpledbf

# %%
#download data, is necesary to have a folder /data
url = 'http://www.indec.gob.ar/ftp/cuadros/menusuperior/eph/t310_dbf.zip'
os.system('wget ' + url)
os.system("mv " + 't310_dbf.zip data')
os.system('unzip data/t310_dbf.zip -d data/ephDBF')
# Out:
# 0

# %%
dbf = simpledbf.Dbf5('data/ephDBF/Individual_t310.dbf',codec='latin1')
indRaw = dbf.to_dataframe()
indRaw.head()
# Out:
#    CODUSU  NRO_HOGAR  COMPONENTE  H15  ANO4  TRIMESTRE  REGION MAS_500  \
# 0  301358          1           1    1  2010          3      43       S
# 1  304669          1           1    1  2010          3      43       S
# 2  304669          1           2    1  2010          3      43       S
# 3  304669          1           3    1  2010          3      43       S
# 4  302366          1           1    1  2010          3      43       S
#
#    AGLOMERADO  PONDERA   ...    DECCFR  IDECCFR  RDECCFR  GDECCFR  PDECCFR  \
# 0           2      647   ...        02       02       02       02      NaN
# 1           2      417   ...        04       04       03       03      NaN
# 2           2      417   ...        04       04       03       03      NaN
# 3           2      417   ...        04       04       03       03      NaN
# 4           2      715   ...        10       10       10       10      NaN
#
#    ADECCFR  PJ1_1  PJ2_1  PJ3_1  IDIMPP
# 0       01      0      0      0   00010
# 1       03      0      0      0   10000
# 2       03      0      0      0   10000
# 3       03      0      0      0   00000
# 4       10      0      0      0   00000
#
# [5 rows x 176 columns]

# %%
indNoW = indRaw.loc[indRaw.REGION == 1,['CODUSU',
                    'NRO_HOGAR',
                    'COMPONENTE',
                    'AGLOMERADO',
                    'PONDERA',
                    'CH03',
                    'CH04',
                    'CH06',
                    'CH10',
                    'CH12',
                    'CH13',
                    'CH14',
                    'ESTADO',
                    'CAT_OCUP',
                    'CAT_INAC',
                    'ITF',
                    'IPCF',
                    'P47T']]
indNoW.head()
# Out:
#        CODUSU  NRO_HOGAR  COMPONENTE  AGLOMERADO  PONDERA  CH03  CH04  CH06  \
# 44316  302468          1           1          32     1287     1     2    20
# 44317  302468          1           2          32     1287    10     2    20
# 44318  307861          1           1          32     1674     1     1    42
# 44319  307861          1           2          32     1674     2     2    44
# 44320  307861          1           3          32     1674     3     1    13
#
#        CH10  CH12  CH13 CH14  ESTADO  CAT_OCUP  CAT_INAC   ITF    IPCF  P47T
# 44316     1     7     2   01       3         0         3  4000  2000.0  2000
# 44317     1     6     2   01       3         0         3  4000  2000.0  2000
# 44318     2     2     1  NaN       1         3         0  5800  1450.0  3000
# 44319     2     7     1  NaN       1         3         0  5800  1450.0  2800
# 44320     1     4     2   00       3         0         3  5800  1450.0     0

# %%
indNoW.columns = ['CODUSU',
                    'NRO_HOGAR',
                    'COMPONENTE',
                    'AGLOMERADO',
                    'PONDERA',
                    'familyRelation', 
                    'female',
                    'age',
                    'schooled',
                    'schoolYear',
                    'finishedYear',
                    'lastYear',
                    'activity',
                    'unempCond',
                    'empCond',
                    'ITF',
                    'IPCF',
              'P47T']
indNoW.index =range(0,indNoW.shape[0])

indNoW.head()
# Out:
#    CODUSU  NRO_HOGAR  COMPONENTE  AGLOMERADO  PONDERA  familyRelation  female  \
# 0  302468          1           1          32     1287               1       2
# 1  302468          1           2          32     1287              10       2
# 2  307861          1           1          32     1674               1       1
# 3  307861          1           2          32     1674               2       2
# 4  307861          1           3          32     1674               3       1
#
#    age  schooled  schoolYear  finishedYear lastYear  activity  unempCond  \
# 0   20         1           7             2       01         3          0
# 1   20         1           6             2       01         3          0
# 2   42         2           2             1      NaN         1          3
# 3   44         2           7             1      NaN         1          3
# 4   13         1           4             2       00         3          0
#
#    empCond   ITF    IPCF  P47T
# 0        3  4000  2000.0  2000
# 1        3  4000  2000.0  2000
# 2        0  5800  1450.0  3000
# 3        0  5800  1450.0  2800
# 4        3  5800  1450.0     0

# %%
indNoW.to_csv('data/cleanData.csv', index = False)
